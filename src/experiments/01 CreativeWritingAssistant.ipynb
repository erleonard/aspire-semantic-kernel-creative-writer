# %% [markdown]
# # Configuration
#
# Define settings for remote services, create `appsettings.Development.json` using `appsettings.json` as template.
#
# You need to manually give yourself
# - `Cognitive Services OpenAI Contributor` rights on the `Azure OpenAI` resource
# - `Search Index Data Contributor` right on the `Azure AI Search` resource
#
# if you not already have it.
#
# Also ensure to execute `azd auth login` to have access to the Azure resources.
#
# > This example is based on [Creative Writing Assistant: Working with Agents using Prompty (Python Implementation)](https://github.com/Azure-Samples/contoso-creative-writer/tree/main).

# %% [markdown]
# # Install and Import Required Packages
# Install and import the necessary packages using NuGet.

# %%
// Install the necessary packages using NuGet
#r "nuget: Azure.Identity, 1.13.1"
#r "nuget: CsvHelper, 33.0.1"
#r "nuget: Microsoft.Extensions.Configuration, 9.0.0"
#r "nuget: Microsoft.Extensions.Configuration.Binder, 9.0.0"
#r "nuget: Microsoft.Extensions.Configuration.UserSecrets, 9.0.0"
#r "nuget: Microsoft.Extensions.Configuration.EnvironmentVariables, 9.0.0"
#r "nuget: Microsoft.Extensions.Http.Resilience, 9.0.0"
#r "nuget: Microsoft.SemanticKernel, 1.33.0"
#r "nuget: Microsoft.SemanticKernel.Plugins.Core, 1.33.0-alpha"
#r "nuget: Microsoft.SemanticKernel.Plugins.Web, 1.33.0-alpha"
#r "nuget: Microsoft.SemanticKernel.Yaml, 1.33.0"
#r "nuget: Microsoft.SemanticKernel.Agents.Core, 1.33.0-alpha"
#r "nuget: Microsoft.SemanticKernel.Connectors.AzureAISearch, 1.33.0-preview"
#r "nuget: Microsoft.SemanticKernel.Connectors.AzureOpenAI, 1.33.0"
#r "nuget: Microsoft.SemanticKernel.Connectors.InMemory, 1.33.0-preview"

// Import the necessary libraries
using System;
using System.Threading;
using System.Net;
using System.ComponentModel;
using System.Diagnostics;
using System.IO;
using System.Text.Json;
using System.Threading.Tasks;
using System.Globalization;
using Azure.Identity;
using CsvHelper;
using Microsoft.DotNet.Interactive;
using Microsoft.Extensions.Configuration;
using Microsoft.Extensions.DependencyInjection;
using Microsoft.Extensions.VectorData;
using Microsoft.Extensions.Http.Resilience;
using Microsoft.SemanticKernel;
using Microsoft.SemanticKernel.Agents;
using Microsoft.SemanticKernel.Agents.Chat;
using Microsoft.SemanticKernel.Agents.History;
using Microsoft.SemanticKernel.ChatCompletion;
using Microsoft.SemanticKernel.Connectors.AzureAISearch;
using Microsoft.SemanticKernel.Connectors.AzureOpenAI;
using Microsoft.SemanticKernel.Connectors.InMemory;
using Microsoft.SemanticKernel.Data;
using Microsoft.SemanticKernel.Embeddings;
using Microsoft.SemanticKernel.Plugins.Web.Bing;
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Azure.Identity, 1.13.1</span></li><li><span>CsvHelper, 33.0.1</span></li><li><span>Microsoft.Extensions.Configuration, 9.0.0</span></li><li><span>Microsoft.Extensions.Configuration.Binder, 9.0.0</span></li><li><span>Microsoft.Extensions.Configuration.EnvironmentVariables, 9.0.0</span></li><li><span>Microsoft.Extensions.Configuration.UserSecrets, 9.0.0</span></li><li><span>Microsoft.Extensions.Http.Resilience, 9.0.0</span></li><li><span>Microsoft.SemanticKernel, 1.33.0</span></li><li><span>Microsoft.SemanticKernel.Agents.Core, 1.33.0-alpha</span></li><li><span>Microsoft.SemanticKernel.Connectors.AzureAISearch, 1.33.0-preview</span></li><li><span>Microsoft.SemanticKernel.Connectors.AzureOpenAI, 1.33.0</span></li><li><span>Microsoft.SemanticKernel.Connectors.InMemory, 1.33.0-preview</span></li><li><span>Microsoft.SemanticKernel.Plugins.Core, 1.33.0-alpha</span></li><li><span>Microsoft.SemanticKernel.Plugins.Web, 1.33.0-alpha</span></li><li><span>Microsoft.SemanticKernel.Yaml, 1.33.0</span></li></ul></div></div>

# %% [markdown]
# # Create Kernel Builder
# Create a Kernel builder instance.

# %%
// The Agent Framework is experimental and requires warning suppression
#pragma warning disable CA2007, IDE1006, SKEXP0050, SKEXP0001, SKEXP0110, SKEXP0010, OPENAI001

var configBuilder = new ConfigurationBuilder()
    .SetBasePath(Directory.GetCurrentDirectory())
    .AddJsonFile("./appsettings.json", optional: false)
    .AddJsonFile("./appsettings.Development.json", optional: false);   
var configuration = configBuilder.Build();

// Create an embedding generation service.
var textEmbeddingGeneration = new AzureOpenAITextEmbeddingGenerationService(
    configuration["EmbeddingModelDeployment"],
    configuration["Endpoint"],
    new AzureDeveloperCliCredential());

// Construct an InMemory vector store.
var vectorStore = new InMemoryVectorStore();
var collectionName = "products";

private sealed class ProductDataModel
{
    [VectorStoreRecordKey]
    public Guid? Key { get; set; }

    [VectorStoreRecordData]
    [TextSearchResultName]
    public string Name { get; set; }

    [VectorStoreRecordData]
    [TextSearchResultValue]
    public string Content { get; set; }

    [VectorStoreRecordVector(1536)]
    public ReadOnlyMemory<float> Embedding { get; set; }
}

// Get and create collection if it doesn't exist.
var recordCollection = vectorStore.GetCollection<Guid, ProductDataModel>(collectionName);
await recordCollection.CreateCollectionIfNotExistsAsync();

using (var reader = new StreamReader("./../data/products.csv"))
using (var csv = new CsvReader(reader, CultureInfo.InvariantCulture))
{
    var records = csv.GetRecords<dynamic>().ToList();

    foreach (var record in records)
    {
        var product = new ProductDataModel
        {
            Key = Guid.NewGuid(),
            Name = record.Name,
            Content = record.Content,
            Embedding = await textEmbeddingGeneration.GenerateEmbeddingAsync((string)record.Name + "" + (string)record.Content)
        };
        await recordCollection.UpsertAsync(product);
    }
}

IKernelBuilder builder = Microsoft.SemanticKernel.Kernel
    .CreateBuilder()
    .AddAzureOpenAIChatCompletion(
        configuration["ChatModelDeployment"],
        configuration["Endpoint"],
        new AzureDeveloperCliCredential());

builder.Services.ConfigureHttpClientDefaults(c =>
{
    c.AddStandardResilienceHandler().Configure(o =>
    {
        o.TotalRequestTimeout.Timeout = TimeSpan.FromSeconds(120);
        o.AttemptTimeout.Timeout = TimeSpan.FromSeconds(60);
        o.CircuitBreaker.SamplingDuration = TimeSpan.FromSeconds(120);
    });
});

private sealed class FunctionInvocationFilter() : IFunctionInvocationFilter
{
    public async Task OnFunctionInvocationAsync(FunctionInvocationContext context, Func<FunctionInvocationContext, Task> next)
    {
        if (context.Function.PluginName == "SearchPlugin")
        {
            Console.WriteLine($"{context.Function.Name}:{JsonSerializer.Serialize(context.Arguments)}");
        }
        await next(context);
    }
}

builder.Services.AddSingleton<IFunctionInvocationFilter, FunctionInvocationFilter>();

Microsoft.SemanticKernel.Kernel kernel = builder.Build();

Microsoft.SemanticKernel.Kernel bingKernel = kernel.Clone();
var textSearch = new BingTextSearch(apiKey: configuration["BingAPIKey"]);
var searchPlugin = textSearch.CreateWithSearch("SearchPlugin");
bingKernel.Plugins.Add(searchPlugin);

Microsoft.SemanticKernel.Kernel vectorSearchKernel = kernel.Clone();
var vectorTextSearch = new VectorStoreTextSearch<ProductDataModel>(recordCollection, textEmbeddingGeneration);
var vectorSearchPlugin = vectorTextSearch.CreateWithGetTextSearchResults("SearchPlugin");
vectorSearchKernel.Plugins.Add(vectorSearchPlugin);

# %% [markdown]
# # Create Researcher and Marketing agents, execute them

# %%
// The Agent Framework is experimental and requires warning suppression
#pragma warning disable CA2007, IDE1006, SKEXP0001, SKEXP0110, OPENAI001

const string ResearcherName = "Researcher";
const string MarketingName = "Marketing";
const string WriterName = "Writer";
const string EditorName = "Editor";

string researcherYaml = File.ReadAllText("./../ChatApp.WebApi/Agents/Prompts/researcher.yaml");
ChatCompletionAgent researcherAgent =
    new(KernelFunctionYaml.ToPromptTemplateConfig(researcherYaml))
    {
        Name = ResearcherName,
        Kernel = bingKernel,
        Arguments =
            new KernelArguments(
                new AzureOpenAIPromptExecutionSettings() 
                { 
                    FunctionChoiceBehavior = FunctionChoiceBehavior.Auto() 
                })
    };

string marketingYaml = File.ReadAllText("./../ChatApp.WebApi/Agents/Prompts/marketing.yaml");
ChatCompletionAgent marketingAgent =
    new(KernelFunctionYaml.ToPromptTemplateConfig(marketingYaml))
    {
        Name = MarketingName,
        Kernel = vectorSearchKernel,
        Arguments =
            new KernelArguments(
                new AzureOpenAIPromptExecutionSettings() 
                { 
                    FunctionChoiceBehavior = FunctionChoiceBehavior.Auto() 
                })
    };

var researchContext = "Can you find the camping trends in 2024 and what folks are doing in this winter?";
var productContext = "Can you use a selection of tents and sleeping bags as context?";
var assignment = @"Write a fun and engaging article that includes the research and product information. 
                    The article should be between 600 and 800 words.
                    Make sure to cite sources in the article as you mention the research not at the end.";

StringBuilder sbResearchResults = new();
await foreach (ChatMessageContent response in researcherAgent.InvokeAsync(new ChatHistory(), new(){{ "research_context", researchContext } }))
{
    Console.WriteLine();
    Console.WriteLine($"{response.AuthorName.ToUpperInvariant()}:{Environment.NewLine}{response.Content}");
    sbResearchResults.AppendLine(response.Content);
}

StringBuilder sbProductResults = new();
await foreach (ChatMessageContent response in marketingAgent.InvokeAsync(new ChatHistory(), new(){{ "product_context", productContext } }))
{
    Console.WriteLine();
    Console.WriteLine($"{response.AuthorName.ToUpperInvariant()}:{Environment.NewLine}{response.Content}");
    sbProductResults.AppendLine(response.Content);
}
# Out:
# Search:{"query":"camping trends 2024","count":"3"}
# Search:{"query":"winter camping activities 2024","count":"3"}
#
# RESEARCHER:
# ## Camping Trends in 2024
# The camping trends for 2024 highlight that camping is more than just a temporary escape into the wild—it signifies an active decision to appreciate, protect, and experience nature in its fullest. Here are some key trends:
#
# 1. **Eco-Friendly Camping**: More campers are opting for sustainable practices, including using eco-friendly camping gear and minimizing their environmental impact.
# 2. **Tech-Enhanced Camping**: The integration of technology in camping gear, like solar-powered equipment and portable wifi solutions, is increasing.
# 3. **Health and Wellness Camping**: There is a rising trend in camping experiences that focus on health and wellness, such as yoga retreats and wellness camps.
# 4. **Adventure Camping**: Activities like rock climbing, mountain biking, and water sports are becoming more popular, making camping an adventure-packed experience.
# 5. **Glamping**: Luxury camping, or glamping, continues to gain popularity, offering comfort and amenities for those who want to enjoy nature without giving up luxury.
#
# ## Winter Camping Activities in 2024
# Winter camping is becoming increasingly popular, with certain destinations and activities gaining significant attention:
#
# 1. **Popular Winter Camping Destinations**: Some of the most popular winter camping destinations in 2024 include locations by the Baltic Sea, the Mediterranean, and several scenic spots in Europe.
# 2. **Cold Weather Activities**: Campers are engaging in activities like snowshoeing, ice fishing, and winter hiking.
# 3. **Warm Winter Camping**: For those who prefer milder climates, destinations with milder winters and beautiful scenery, such as southern European regions, are favorable.
# 4. **Christmas Camping**: Combining camping with holiday festivities, many campers are choosing to spend Christmas at campsites that offer themed events and decorations.
# 5. **Hot Springs and Thermal Baths**: Camping near hot springs or thermal baths during winter is a popular way to add warmth and relaxation to the camping experience.
#
# These trends and activities indicate a blend of adventure, sustainability, technology, and comfort in the evolving camping landscape.
# GetTextSearchResults:{"query":"best family tents","count":"2"}
# GetTextSearchResults:{"query":"lightweight tents for backpacking","count":"2"}
# GetTextSearchResults:{"query":"top-rated sleeping bags for winter camping","count":"2"}
# GetTextSearchResults:{"query":"affordable sleeping bags for summer","count":"2"}
# GetTextSearchResults:{"query":"best tent brands","count":"2"}
#
# MARKETING:
# Here are some specialized queries, and the corresponding results, to help you in writing marketing articles about tents and sleeping bags:
#
# 1. **Best Family Tents**:
#    - **Alpine Explorer Tent**: This robust 8-person, 3-season tent from AlpineGear offers an easy setup, detachable divider for privacy, breathable mesh windows, adjustable vents, and waterproof assurance. It's equipped with a built-in gear loft for convenience. [Link Unavailable]
#    - **TrailMaster X4 Tent**: A 4-person tent by OutdoorLiving made from durable polyester, featuring water-resistant construction, mesh panels for airflow, multiple doors, and interior pockets for small items. It includes reflective guy lines and a freestanding design for easy setup. [Link Unavailable]
#
# 2. **Lightweight Tents for Backpacking**:
#    - **SkyView 2-Person Tent**: This tent from OutdoorLiving offers a spacious interior for two people, crafted from durable waterproof materials, and features an easy setup with color-coded poles. It includes mesh panels for ventilation, a rainfly for weather protection, and reflective guy lines. [Link Unavailable]
#    - **Alpine Explorer Tent**: Detailed previously, this 8-person tent provides a balance of privacy, comfort, and convenience, making it suitable for family camping and backpacking with a larger group. [Link Unavailable]
#
# 3. **Top-Rated Sleeping Bags for Winter Camping**:
#    - **MountainDream Sleeping Bag**: A 3-season sleeping bag with premium synthetic insulation, durable water-resistant nylon shell, and breathable polyester lining. It features a contoured mummy shape, snag-free YKK zipper, adjustable hood, and full-length zipper baffle. Includes an interior pocket and a compression sack for easy storage. [Link Unavailable]
#    - **CozyNights Sleeping Bag**: A lightweight, 3-season bag designed for comfort during spring, summer, and fall, featuring a compact design, ample room and padding, and reliable temperature rating. It can be zipped together with another bag. [Link Unavailable]
#
# 4. **Affordable Sleeping Bags for Summer**:
#    - **CozyNights Sleeping Bag**: Described above, this affordable sleeping bag offers comfort and warmth for various outdoor adventures with its compact design and quality features. [Link Unavailable]
#    - **MountainDream Sleeping Bag**: Also described previously, it provides a warm and durable option for camping in different seasons with its high-quality materials and design. [Link Unavailable]
#
# 5. **Best Tent Brands**:
#    - **AlpineGear**: Known for producing the Alpine Explorer Tent, this brand focuses on creating robust, easy-to-setup tents with features like detachable dividers, numerous mesh windows, and built-in gear lofts.
#    - **OutdoorLiving**: Offers products like the TrailMaster X4 Tent and SkyView 2-Person Tent, emphasizing durability, water-resistant construction, ease of setup, and effective ventilation in their designs.
#
# These results offer detailed insights into various tents and sleeping bags suitable for different camping needs, which will be useful for your marketing content.

# %% [markdown]
# # Creat Writer and Editor agents, put them into Group Chat

# %%
// The Agent Framework is experimental and requires warning suppression
#pragma warning disable CA2007, IDE1006, SKEXP0001, SKEXP0110, OPENAI001

private sealed class NoFeedbackLeftTerminationStrategy : TerminationStrategy
{
    // Terminate when the final message contains the term "Article accepted, no further rework necessary." - all done
    protected override Task<bool> ShouldAgentTerminateAsync(Agent agent, IReadOnlyList<ChatMessageContent> history, CancellationToken cancellationToken)
    {
        if(agent.Name != EditorName)
            return Task.FromResult(false);

        return Task.FromResult(history[history.Count - 1].Content?.Contains("Article accepted", StringComparison.OrdinalIgnoreCase) ?? false);
    }
}



string writerYaml = File.ReadAllText("./../ChatApp.WebApi/Agents/Prompts/writer.yaml");
ChatCompletionAgent writerAgent =
    new(KernelFunctionYaml.ToPromptTemplateConfig(writerYaml))
    {
        Name = WriterName,
        Kernel = kernel,
        Arguments = new()
    };

string editorYaml = File.ReadAllText("./../ChatApp.WebApi/Agents/Prompts/editor.yaml");
ChatCompletionAgent editorAgent =
    new(KernelFunctionYaml.ToPromptTemplateConfig(editorYaml))
    {
        Name = EditorName,
        Kernel = kernel,
    };

AgentGroupChat chat =
    new(writerAgent, editorAgent)
    {
        ExecutionSettings = new AgentGroupChatSettings
        {
            SelectionStrategy = new SequentialSelectionStrategy(){ InitialAgent = writerAgent },
            TerminationStrategy = new NoFeedbackLeftTerminationStrategy()
        }
    };

Console.WriteLine("Ready!");
# Out:
# Ready!

# %% [markdown]
# # Execute Group Chat

# %%
// The Agent Framework is experimental and requires warning suppression
#pragma warning disable CA2007, IDE1006, SKEXP0001, SKEXP0110, OPENAI001

writerAgent.Arguments["research_context"] = researchContext;
writerAgent.Arguments["research_results"] = sbResearchResults.ToString();
writerAgent.Arguments["product_context"] = productContext;
writerAgent.Arguments["product_results"] = sbProductResults.ToString();
writerAgent.Arguments["assignment"] = assignment;

try
{
    await foreach (ChatMessageContent response in chat.InvokeAsync())
    {
        Console.WriteLine();
        Console.WriteLine("------------------------");
        Console.WriteLine($"{response.AuthorName.ToUpperInvariant()}:{Environment.NewLine}{response.Content}");
    }
}
catch (HttpOperationException exception)
{
    Console.WriteLine(exception.Message);
    if (exception.InnerException != null)
    {
        Console.WriteLine(exception.InnerException.Message);
        if (exception.InnerException.Data.Count > 0)
        {
            Console.WriteLine(JsonSerializer.Serialize(exception.InnerException.Data, new JsonSerializerOptions() { WriteIndented = true }));
        }
    }
}
# Out:
# ------------------------
# WRITER:
# # The Ultimate Camping Guide: Trends and Gear for 2024
#
# Are you an avid camper or just getting started on your outdoor adventures? Either way, 2024 brings exciting new camping trends that blend sustainability, technology, and a touch of luxury. Let's take a look at what this year's camping scene has to offer and the top gear to make your experience unforgettable.
#
# ## Camping Trends in 2024
#
# ### 1. Eco-Friendly Camping
#
# In 2024, eco-friendly camping is more than a trend—it's a lifestyle choice. Campers are increasingly mindful of their environmental impact, opting for sustainable practices like using solar-powered gear, reusable water bottles, and biodegradable products. Brands are responding with eco-friendly options such as the Alpine Explorer Tent from AlpineGear, featuring breathable mesh windows and adjustable vents, all designed to work harmoniously with nature.
#
# ### 2. Tech-Enhanced Camping
#
# Technology is making its way into the wilderness, changing how we camp. From solar-powered chargers to portable WiFi, tech-enhanced camping is booming. Imagine setting up your TrailMaster X4 Tent from OutdoorLiving and pairing it with solar panels to power your devices while enjoying the great outdoors. This tent, made of durable polyester with water-resistant construction, ensures you stay connected and comfortable, even when miles from civilization.
#
# ### 3. Health and Wellness Camping
#
# Camping is becoming a holistic wellness retreat. Health and wellness camping experiences, such as yoga retreats and mindfulness camps, draw campers seeking physical and mental rejuvenation in nature. Whether you're a yoga enthusiast or simply want to unwind, combining camping with wellness activities is a trend we can all appreciate.
#
# ### 4. Adventure Camping
#
# For thrill-seekers, adventure camping is the way to go. Incorporating activities like rock climbing, mountain biking, and water sports, adventure camping turns your trip into an action-packed experience. Gear up with a tent like the SkyView 2-Person Tent from OutdoorLiving, designed for durability and easy setup, ensuring you're ready for whatever adventure comes your way.
#
# ### 5. Glamping
#
# If luxury camping, or glamping, is more your style, you're in luck—this trend continues to grow. Glamping offers all the amenities of a hotel with the beauty of the outdoors. Imagine a weekend getaway in a cozy, fully-equipped tent like the Alpine Explorer Tent, complete with a built-in gear loft and detachable divider for privacy. Glamping merges comfort and nature, creating a perfect escape from the hustle and bustle of everyday life.
#
# ## Winter Camping Activities in 2024
#
# Winter camping, once considered a test of endurance, has become a beloved activity with unique destinations and engaging activities.
#
# ### Popular Winter Camping Destinations
#
# Chilly yet stunning landscapes are drawing campers to new winter destinations. Camp along the Baltic Sea or the Mediterranean and enjoy the serene beauty of Europe's scenic spots. These locations offer breathtaking views and a peaceful retreat from crowded campsites.
#
# ### Cold Weather Activities
#
# Cold-weather activities add excitement to winter camping. Snowshoeing, ice fishing, and winter hiking are just some of the ways campers stay active and warm during the colder months. With a MountainDream Sleeping Bag, featuring a water-resistant nylon shell and premium synthetic insulation, you'll stay cozy after a day spent exploring snowy trails.
#
# ### Warm Winter Camping
#
# Not all winter camping needs to be in freezing temperatures. Milder climates, such as the southern regions of Europe, provide a perfect winter getaway with beautiful scenery and pleasant weather. The CozyNights Sleeping Bag, with its lightweight and compact design, is ideal for such trips, providing comfort without the bulk.
#
# ### Christmas Camping
#
# How about spending Christmas under the stars? Christmas camping combines holiday festivities with the joy of camping. Campgrounds are adorned with themed decorations and events, making it a magical way to celebrate the season.
#
# ### Hot Springs and Thermal Baths
#
# For a true winter treat, camping near hot springs or thermal baths is unbeatable. These natural warm waters are perfect for relaxing and rejuvenating. Nearby campsites offer easy access, allowing you to soak in the warmth while being surrounded by nature's winter beauty.
#
# ## Must-Have Gear for 2024
#
# Your camping experience can be made or broken by the gear you choose. Here are some top picks for tents and sleeping bags to ensure your 2024 camping trips are memorable:
#
# ### Tents
#
# - **Alpine Explorer Tent**: With a capacity for eight people, this tent from AlpineGear is perfect for family trips. It features easy setup, a detachable divider for privacy, breathable mesh windows, and a built-in gear loft.
# - **TrailMaster X4 Tent**: Ideal for smaller groups, this four-person tent from OutdoorLiving includes multiple doors for easy access, water-resistant construction, and mesh panels for ventilation.
#
# ### Sleeping Bags
#
# - **MountainDream Sleeping Bag**: Designed for three seasons, this sleeping bag boasts premium synthetic insulation, a durable water-resistant nylon shell, and an adjustable hood, making it perfect for winter camping.
# - **CozyNights Sleeping Bag**: This lightweight and comfortable sleeping bag is great for warmer weather camping. It offers ample padding, a compact design, and the ability to zip together with another bag for added space.
#
# ## Conclusion
#
# Camping in 2024 is all about embracing nature with a touch of innovation. Whether you're an eco-warrior, a tech enthusiast, an adventurer, or someone who enjoys a bit of luxury, there's a trend and gear perfect for your next outdoor adventure. So pack up your Alpine Explorer Tent, slip into your MountainDream Sleeping Bag, and get ready to explore the wonders of the wild in 2024. Happy camping!
#
# ------------------------
# EDITOR:
# *Review Feedback*
#
# 1. In the section "Eco-Friendly Camping," consider providing specific examples of eco-friendly products other than the already mentioned tent.
# 2. For the “Tech-Enhanced Camping” section, ensure you elaborate slightly more on specific tech gear besides the charger and WiFi, perhaps mentioning GPS devices or camp stoves.
# 3. The "Health and Wellness Camping" section might benefit from including specific brands or types of wellness-focused camping gear or experiences.
# 4. Consider expanding the "Adventure Camping" section by providing detailed examples of suitable gear for rock climbing, mountain biking, and water sports.
# 5. For consistency, make sure each trend section provides a balanced amount of detail and specific examples.
# 6. Ensure that the connection between “Christmas Camping” and the thematic decorations/events is clearer.
# 7. Check for repetitive use of certain words or phrases and aim for more variety.
# 8. In the "Warm Winter Camping" section, clarify why milder climates are beneficial for winter camping, perhaps mentioning specific destinations known for their pleasant winter weather.
#
# Ensure you address these points to improve the clarity and detail of the article.
#
# ------------------------
# WRITER:
# # The Ultimate Camping Guide: Trends and Gear for 2024
#
# Are you an avid camper or just getting started on your outdoor adventures? Either way, 2024 brings exciting new camping trends that blend sustainability, technology, and a touch of luxury. Let's take a look at what this year's camping scene has to offer and the top gear to make your experience unforgettable.
#
# ## Camping Trends in 2024
#
# ### 1. Eco-Friendly Camping
#
# In 2024, eco-friendly camping is more than a trend—it's a lifestyle choice. Campers are increasingly mindful of their environmental impact, opting for sustainable practices like using solar-powered gear, reusable water bottles, and biodegradable products. Brands are responding with eco-friendly options such as bamboo utensils, compostable waste bags, and solar-powered lanterns. The Alpine Explorer Tent from AlpineGear, featuring breathable mesh windows and adjustable vents, is just one example of how eco-friendly designs are revolutionizing camping gear.
#
# ### 2. Tech-Enhanced Camping
#
# Technology is making its way into the wilderness, changing how we camp. From solar-powered chargers to portable WiFi, tech-enhanced camping is booming. Imagine setting up your TrailMaster X4 Tent from OutdoorLiving and pairing it with solar panels to power your devices while enjoying the great outdoors. This tent, made of durable polyester with water-resistant construction, ensures you stay connected and comfortable, even when miles from civilization. Additionally, GPS devices, smart camp stoves, and portable weather stations are becoming must-have gadgets to enhance your camping experience.
#
# ### 3. Health and Wellness Camping
#
# Camping is becoming a holistic wellness retreat. Health and wellness camping experiences, such as yoga retreats and mindfulness camps, draw campers seeking physical and mental rejuvenation in nature. Brands like YOGO and Manduka offer travel-friendly yoga mats, while Cookware brands like Sea to Summit provide lightweight and compact gear ideal for preparing healthy meals outdoors. Whether you're a yoga enthusiast or simply want to unwind, combining camping with wellness activities is a trend we can all appreciate.
#
# ### 4. Adventure Camping
#
# For thrill-seekers, adventure camping is the way to go. Incorporating activities like rock climbing, mountain biking, and water sports, adventure camping turns your trip into an action-packed experience. Gear up with a tent like the SkyView 2-Person Tent from OutdoorLiving, designed for durability and easy setup, ensuring you're ready for whatever adventure comes your way. Don't forget to pack climbing harnesses, mountain bikes, and inflatable kayaks to fully immerse yourself in the adventure-packed camping trend.
#
# ### 5. Glamping
#
# If luxury camping, or glamping, is more your style, you're in luck—this trend continues to grow. Glamping offers all the amenities of a hotel with the beauty of the outdoors. Imagine a weekend getaway in a cozy, fully-equipped tent like the Alpine Explorer Tent, complete with a built-in gear loft and detachable divider for privacy. Glamping merges comfort and nature, creating a perfect escape from the hustle and bustle of everyday life. Enjoy amenities such as portable showers, gourmet camp kitchens, and plush bedding to elevate your glamping experience.
#
# ## Winter Camping Activities in 2024
#
# Winter camping, once considered a test of endurance, has become a beloved activity with unique destinations and engaging activities.
#
# ### Popular Winter Camping Destinations
#
# Chilly yet stunning landscapes are drawing campers to new winter destinations. Camp along the Baltic Sea or the Mediterranean and enjoy the serene beauty of Europe’s scenic spots. These locations offer breathtaking views and a peaceful retreat from crowded campsites, with picturesque winter wonderlands that make braving the cold worthwhile.
#
# ### Cold Weather Activities
#
# Cold-weather activities add excitement to winter camping. Snowshoeing, ice fishing, and winter hiking are just some of the ways campers stay active and warm during the colder months. With a MountainDream Sleeping Bag, featuring a water-resistant nylon shell and premium synthetic insulation, you'll stay cozy after a day spent exploring snowy trails. For added warmth, consider bringing along heated gloves and thermal blankets.
#
# ### Warm Winter Camping
#
# Not all winter camping needs to be in freezing temperatures. Milder climates, such as the southern regions of Europe, provide a perfect winter getaway with beautiful scenery and pleasant weather. Destination spots in southern Spain, Italy, and Greece are ideal for enjoying winter camping without battling extreme cold. The CozyNights Sleeping Bag, with its lightweight and compact design, is ideal for such trips, providing comfort without the bulk. Enjoy activities like mild-weather hiking and beachside camping to make the most of these temperate winter destinations.
#
# ### Christmas Camping
#
# How about spending Christmas under the stars? Christmas camping combines holiday festivities with the joy of camping. Many campgrounds are adorned with themed decorations and events, making it a magical way to celebrate the season. From festive lighting to Christmas market-inspired food stalls, campgrounds offer a holiday experience that blends traditional cheer with the serenity of the great outdoors.
#
# ### Hot Springs and Thermal Baths
#
# For a true winter treat, camping near hot springs or thermal baths is unbeatable. These natural warm waters are perfect for relaxing and rejuvenating. Nearby campsites offer easy access, allowing you to soak in the warmth while being surrounded by nature's winter beauty. Consider destinations like Iceland's Blue Lagoon or Japan's onsen towns for the ultimate hot springs camping experience.
#
# ## Must-Have Gear for 2024
#
# Your camping experience can be made or broken by the gear you choose. Here are some top picks for tents and sleeping bags to ensure your 2024 camping trips are memorable:
#
# ### Tents
#
# - **Alpine Explorer Tent**: With a capacity for eight people, this tent from AlpineGear is perfect for family trips. It features easy setup, a detachable divider for privacy, breathable mesh windows, and a built-in gear loft.
# - **TrailMaster X4 Tent**: Ideal for smaller groups, this four-person tent from OutdoorLiving includes multiple doors for easy access, water-resistant construction, and mesh panels for ventilation.
#
# ### Sleeping Bags
#
# - **MountainDream Sleeping Bag**: Designed for three seasons, this sleeping bag boasts premium synthetic insulation, a durable water-resistant nylon shell, and an adjustable hood, making it perfect for winter camping.
# - **CozyNights Sleeping Bag**: This lightweight and comfortable sleeping bag is great for warmer weather camping. It offers ample padding, a compact design, and the ability to zip together with another bag for added space.
#
# ## Conclusion
#
# Camping in 2024 is all about embracing nature with a touch of innovation. Whether you're an eco-warrior, a tech enthusiast, an adventurer, or someone who enjoys a bit of luxury, there's a trend and gear perfect for your next outdoor adventure. So pack up your Alpine Explorer Tent, slip into your MountainDream Sleeping Bag, and get ready to explore the wonders of the wild in 2024. Happy camping!
#
# ------------------------
# EDITOR:
# Article accepted, no further rework necessary.
